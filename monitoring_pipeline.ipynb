# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
from datasets import load_dataset
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/reinforcement-learning-from-feature-rewards-replication/vllm2/lib64/python3.12/site-packages/transformers/utils/import_utils.py:2249, in _LazyModule.__getattr__(self, name)
#    2248 try:
# -> 2249     module = self._get_module(self._class_to_module[name])
#    2250     value = getattr(module, name)
#
# File ~/reinforcement-learning-from-feature-rewards-replication/vllm2/lib64/python3.12/site-packages/transformers/utils/import_utils.py:2483, in _LazyModule._get_module(self, module_name)
#    2482 except Exception as e:
# -> 2483     raise e
#
# File ~/reinforcement-learning-from-feature-rewards-replication/vllm2/lib64/python3.12/site-packages/transformers/utils/import_utils.py:2481, in _LazyModule._get_module(self, module_name)
#    2480 try:
# -> 2481     return importlib.import_module("." + module_name, self.__name__)
#    2482 except Exception as e:
#
# File /usr/lib64/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1334, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:950, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:999, in _LoaderBasics.exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/reinforcement-learning-from-feature-rewards-replication/vllm2/lib64/python3.12/site-packages/transformers/models/auto/tokenization_auto.py:25
#      23 from transformers.utils.import_utils import is_mistral_common_available
# ---> 25 from ...configuration_utils import PreTrainedConfig
#      26 from ...dynamic_module_utils import get_class_from_dynamic_module, resolve_trust_remote_code
#
# File ~/reinforcement-learning-from-feature-rewards-replication/vllm2/lib64/python3.12/site-packages/transformers/configuration_utils.py:33
#      32 from .dynamic_module_utils import custom_object_save
# ---> 33 from .generation.configuration_utils import GenerationConfig
#      34 from .modeling_gguf_pytorch_utils import load_gguf_checkpoint
#
# File ~/reinforcement-learning-from-feature-rewards-replication/vllm2/lib64/python3.12/site-packages/transformers/generation/configuration_utils.py:62
#      61 if is_torch_available():
# ---> 62     from .logits_process import SynthIDTextWatermarkLogitsProcessor, WatermarkLogitsProcessor
#      65 def _should_warn(outer_attr: str, inner_attr: str, user_set_attributes: set | None) -> bool:
#
# File ~/reinforcement-learning-from-feature-rewards-replication/vllm2/lib64/python3.12/site-packages/transformers/generation/logits_process.py:21
#      20 import numpy as np
# ---> 21 import torch
#      23 from .._typing import WhisperGenerationConfigLike
#
# File ~/reinforcement-learning-from-feature-rewards-replication/vllm2/lib64/python3.12/site-packages/torch/__init__.py:2229
#    2224 ################################################################################
#    2225 # Import interface functions defined in Python
#    2226 ################################################################################
#    2227
#    2228 # needs to be after the above ATen bindings so we can overwrite from Python side
# -> 2229 from torch import _VF as _VF, functional as functional  # usort: skip
#    2230 from torch.functional import *  # usort: skip # noqa: F403
#
# File ~/reinforcement-learning-from-feature-rewards-replication/vllm2/lib64/python3.12/site-packages/torch/functional.py:8
#       7 import torch
# ----> 8 import torch.nn.functional as F
#       9 from torch import _VF, Tensor
#
# File ~/reinforcement-learning-from-feature-rewards-replication/vllm2/lib64/python3.12/site-packages/torch/nn/__init__.py:8
#       2 from torch.nn.parameter import (  # usort: skip
#       3     Buffer as Buffer,
#       4     Parameter as Parameter,
#       5     UninitializedBuffer as UninitializedBuffer,
#       6     UninitializedParameter as UninitializedParameter,
#       7 )
# ----> 8 from torch.nn.modules import *  # usort: skip # noqa: F403
#       9 from torch.nn import (
#      10     attention as attention,
#      11     functional as functional,
#    (...)     16     utils as utils,
#      17 )
#
# File ~/reinforcement-learning-from-feature-rewards-replication/vllm2/lib64/python3.12/site-packages/torch/nn/modules/__init__.py:1
# ----> 1 from .module import Module  # usort: skip
#       2 from .linear import Bilinear, Identity, LazyLinear, Linear  # usort: skip
#
# File ~/reinforcement-learning-from-feature-rewards-replication/vllm2/lib64/python3.12/site-packages/torch/nn/modules/module.py:17
#      16 from torch.nn.parameter import Buffer, Parameter
# ---> 17 from torch.utils._python_dispatch import is_traceable_wrapper_subclass
#      18 from torch.utils.hooks import BackwardHook, RemovableHandle
#
# File ~/reinforcement-learning-from-feature-rewards-replication/vllm2/lib64/python3.12/site-packages/torch/utils/__init__.py:8
#       7 import torch
# ----> 8 from torch.utils import (
#       9     backcompat as backcompat,
#      10     collect_env as collect_env,
#      11     data as data,
#      12     deterministic as deterministic,
#      13     hooks as hooks,
#      14 )
#      15 from torch.utils.backend_registration import (
#      16     generate_methods_for_privateuse1_backend,
#      17     rename_privateuse1_backend,
#      18 )
#
# File ~/reinforcement-learning-from-feature-rewards-replication/vllm2/lib64/python3.12/site-packages/torch/utils/data/__init__.py:1
# ----> 1 from torch.utils.data.dataloader import (
#       2     _DatasetKind,
#       3     DataLoader,
#       4     default_collate,
#       5     default_convert,
#       6     get_worker_info,
#       7 )
#       8 from torch.utils.data.datapipes._decorator import (
#       9     argument_validation,
#      10     functional_datapipe,
#    (...)     14     runtime_validation_disabled,
#      15 )
#
# File ~/reinforcement-learning-from-feature-rewards-replication/vllm2/lib64/python3.12/site-packages/torch/utils/data/dataloader.py:26
#      25 import torch.distributed as dist
# ---> 26 import torch.utils.data.graph_settings
#      27 from torch._utils import ExceptionWrapper
#
# File ~/reinforcement-learning-from-feature-rewards-replication/vllm2/lib64/python3.12/site-packages/torch/utils/data/graph_settings.py:8
#       7 import torch
# ----> 8 from torch.utils.data.datapipes.iter.sharding import (
#       9     _ShardingIterDataPipe,
#      10     SHARDING_PRIORITIES,
#      11 )
#      12 from torch.utils.data.graph import DataPipe, DataPipeGraph, traverse_dps
#
# File ~/reinforcement-learning-from-feature-rewards-replication/vllm2/lib64/python3.12/site-packages/torch/utils/data/datapipes/__init__.py:1
# ----> 1 from torch.utils.data.datapipes import dataframe as dataframe, iter as iter, map as map
#
# File ~/reinforcement-learning-from-feature-rewards-replication/vllm2/lib64/python3.12/site-packages/torch/utils/data/datapipes/iter/__init__.py:1
# ----> 1 from torch.utils.data.datapipes.iter.callable import (
#       2     CollatorIterDataPipe as Collator,
#       3     MapperIterDataPipe as Mapper,
#       4 )
#       5 from torch.utils.data.datapipes.iter.combinatorics import (
#       6     SamplerIterDataPipe as Sampler,
#       7     ShufflerIterDataPipe as Shuffler,
#       8 )
#
# File ~/reinforcement-learning-from-feature-rewards-replication/vllm2/lib64/python3.12/site-packages/torch/utils/data/datapipes/iter/callable.py:8
#       7 import torch
# ----> 8 from torch.utils.data._utils.collate import default_collate
#       9 from torch.utils.data.datapipes._decorator import functional_datapipe
#
# File ~/reinforcement-learning-from-feature-rewards-replication/vllm2/lib64/python3.12/site-packages/torch/utils/data/_utils/__init__.py:53
#      50 atexit.register(_set_python_exit_flag)
# ---> 53 from . import collate, fetch, pin_memory, signal_handling, worker
#
# File ~/reinforcement-learning-from-feature-rewards-replication/vllm2/lib64/python3.12/site-packages/torch/utils/data/_utils/collate.py:330
#     329 # For both ndarray and memmap (subclass of ndarray)
# --> 330 default_collate_fn_map[np.ndarray] = collate_numpy_array_fn
#     331 # See scalars hierarchy: https://numpy.org/doc/stable/reference/arrays.scalars.html
#     332 # Skip string scalars
#
# AttributeError: module 'numpy' has no attribute 'ndarray'
#
# The above exception was the direct cause of the following exception:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from transformers import AutoTokenizer, AutoModelForCausalLM
#       2 from datasets import load_dataset
#
# File ~/reinforcement-learning-from-feature-rewards-replication/vllm2/lib64/python3.12/site-packages/transformers/utils/import_utils.py:2337, in _LazyModule.__getattr__(self, name)
#    2333                     raise ModuleNotFoundError(
#    2334                         f"Could not import module '{name}'. Are this object's requirements defined correctly?"
#    2335                     ) from e
#    2336         else:
# -> 2337             raise ModuleNotFoundError(
#    2338                 f"Could not import module '{name}'. Are this object's requirements defined correctly?"
#    2339             ) from e
#    2341 elif name in self._modules:
#    2342     try:
#
# ModuleNotFoundError: Could not import module 'AutoTokenizer'. Are this object's requirements defined correctly?

# %%
tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen3-8B")
model = AutoModelForCausalLM.from_pretrained("Qwen/Qwen3-8B")
model.to('cuda')
